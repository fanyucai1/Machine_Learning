# %%
#机器学习回归问题的典型指标是均方根误差(RMSE)
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
plt.style.use('ggplot')
warnings.filterwarnings(action="ignore")
boston=load_boston()
sns.set_style("white")
plt.subplots(figsize=(8, 7))
plt.xlabel("Target price")
plt.ylabel("Distribution")
plt.title("house prices")
sns.distplot(boston.target,color='b')
sns.despine(trim=True,left=True)

# %%
pd.DataFrame(boston.target).skew()#偏度
# Out:
# 0    1.108098
# dtype: float64

# %%
pd.DataFrame(boston.target).kurt()#峰度
# Out:
# 0    1.495197
# dtype: float64

# %%
df_data=pd.DataFrame(boston.data)
df_target=pd.DataFrame(boston.target)
